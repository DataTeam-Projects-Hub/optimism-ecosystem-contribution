# %%
import requests
import pandas as pd
import time
import os

# %%
# configuration
API_URL = "https://vote.optimism.io/api/v1/proposals"
AGORA_TOKEN = os.getenv("AGORA_TOKEN")
HEADERS = {
    "Authorization": f"Bearer {AGORA_TOKEN}",
    "Accept": "application/json"
}
LIMIT = 50  
FILTER = "everything"  
SLEEP_BETWEEN_CALLS = 0.2  # To avoid overloading the API
OUTPUT_CSV = "../Data/Agora_Proposals_Data.csv"

proposals = []
offset = 0
has_next = True

while has_next:
    params = {
        "limit": LIMIT,
        "offset": offset,
        "filter": FILTER
    }

    response = requests.get(API_URL, headers=HEADERS, params=params)
    if response.status_code != 200:
        print(f"Error fetching proposals: {response.status_code}")
        break

    data = response.json()
    batch = data["data"]
    meta = data["meta"]

    for item in batch:
        # Proposal results (converted from wei to ether)
        for_votes = int(item["proposalResults"]["for"]) / 1e18 if item["proposalResults"]["for"] else 0
        against_votes = int(item["proposalResults"]["against"]) / 1e18 if item["proposalResults"]["against"] else 0
        abstain_votes = int(item["proposalResults"]["abstain"]) / 1e18 if item["proposalResults"]["abstain"] else 0

        proposals.append({
            "proposal_id": item["id"],
            "proposer": item["proposer"],
            "proposal_creation_date": item["createdTime"],
            "voting_start_time": item["startTime"],
            "voting_end_time": item["endTime"],
            "proposal_title": item["markdowntitle"],
            "proposal_description": item["description"],
            "proposal_quorum": int(item["quorum"]) / 1e18 if item["quorum"] else 0,
            "For_votes": for_votes,
            "Against_votes": against_votes,
            "Abstain_votes": abstain_votes,
            "proposal_type": item["proposalType"],
            "proposal_status": item["status"]
        })

    print(f"Fetched {len(batch)} proposals, offset: {offset}")

    # Pagination
    has_next = meta["has_next"]
    offset = meta.get("next_offset", offset + LIMIT)
    time.sleep(SLEEP_BETWEEN_CALLS)

# Save data to CSV
df = pd.DataFrame(proposals)
df.to_csv(OUTPUT_CSV, index=False)
print(f"\nFinished. {len(df)} proposals saved to '{OUTPUT_CSV}'.")
# Out:
# Fetched 50 proposals, offset: 0
# Fetched 50 proposals, offset: 50
# Fetched 31 proposals, offset: 100
#
# Finished. 131 proposals saved to '../Data/Agora_Proposals_Data.csv'.

# %%
agora_proposals = pd.read_csv("../Data/Agora_Proposals_Data.csv")

# %%
agora_proposals.head()
# Out:
#                                          proposal_id  \
# 0  3505139576575581948952533286313165208104296221...
# 1  1051968506078966263708936047680273814335480361...
# 2  9182817580700389780502258935293441461198117953...
# 3  1099608625850195404769236791570123626409652639...
# 4  8705916809146420472067303211131851783087744913...
#
#                                      proposer    proposal_creation_date  \
# 0  0xe4553b743e74da3424ac51f8c1e586fd43ae226f  2025-06-05T18:02:45.000Z
# 1  0xe4553b743e74da3424ac51f8c1e586fd43ae226f  2025-04-25T18:25:17.000Z
# 2  0xe4553b743e74da3424ac51f8c1e586fd43ae226f  2025-04-24T19:35:35.000Z
# 3  0xe4553b743e74da3424ac51f8c1e586fd43ae226f  2025-04-24T18:00:05.000Z
# 4  0xe4553b743e74da3424ac51f8c1e586fd43ae226f  2025-04-03T18:18:59.000Z
#
#           voting_start_time           voting_end_time  \
# 0  2025-06-05T18:02:45.000Z  2025-06-11T18:02:45.000Z
# 1  2025-04-25T18:25:17.000Z  2025-05-01T18:25:17.000Z
# 2  2025-04-24T19:35:35.000Z  2025-04-30T19:35:35.000Z
# 3  2025-04-24T18:00:05.000Z  2025-04-30T18:00:05.000Z
# 4  2025-04-03T18:18:59.000Z  2025-04-09T18:18:59.000Z
#
#                                       proposal_title  \
# 0  Season 8 and 9 Milestone and Metrics Council S...
# 1  Maintenance Upgrade: Absolute Prestate Updates...
# 2   Season 8 and 9: Budget Board Member Ratification
# 3   Season 8 and 9: Budget Board Member Ratification
# 4            Upgrade Proposal #15: Isthmus Hard Fork
#
#                                 proposal_description  proposal_quorum  \
# 0  # Season 8 and 9 Milestone and Metrics Council...     3.481087e+07
# 1  # Maintenance Upgrade: Absolute Prestate Updat...     3.468349e+07
# 2  # Season 8 and 9: Budget Board Member Ratifica...     3.481087e+07
# 3  # Season 8 and 9: Budget Board Member Ratifica...     3.481087e+07
# 4  # Upgrade Proposal #15: Isthmus Hard Fork\nThi...     3.393043e+07
#
#       For_votes  Against_votes  Abstain_votes proposal_type proposal_status
# 0  2.604167e+07   2.534529e+07   6.106242e+06      STANDARD        DEFEATED
# 1  0.000000e+00   1.788357e+06   0.000000e+00    OPTIMISTIC       SUCCEEDED
# 2  5.214989e+07   1.788403e+05   1.132479e+06      STANDARD        EXECUTED
# 3  8.482038e+05   0.000000e+00   1.122000e+02      STANDARD       CANCELLED
# 4  5.514418e+07   1.223378e+04   1.248278e+05      STANDARD        EXECUTED

# %%
agora_proposals.to_json("../Data/Agora_Proposals_Data.json", orient="records", indent=2, force_ascii=False)
